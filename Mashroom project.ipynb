# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the data

df=pd.read_csv("mashroomdata.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
#to know about the data types of each column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
#to know the null values 

df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset, so we'll do the visualization (EDA) of the dataset to know the more insights of the data.

# %%
for i in df.columns:
    plt.figure(figsize=(6,6))
    sns.countplot(df[i])

# %% [markdown]
# # Label encoding

# %% [markdown]
# Now, we'll do the label encoding to convert the catergorized data into numerical form .

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
for i in df.columns:
    df[i]=lb.fit_transform(df[i])
    
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# As, we can see veil type has only one type of class so we can drop and cap-surface is less correlated .

# %%
df.drop("veil-type",axis=1,inplace=True)

# %%
df.drop("cap-surface",axis=1,inplace=True)

# %%
df.head()
# Out:
#    class  cap-shape  cap-color  bruises  odor  gill-attachment  gill-spacing  \
# 0      1          5          4        1     6                1             0
# 1      0          5          9        1     0                1             0
# 2      0          0          8        1     3                1             0
# 3      1          5          8        1     6                1             0
# 4      0          5          3        0     5                1             1
#
#    gill-size  gill-color  stalk-shape  ...  stalk-surface-above-ring  \
# 0          1           4            0  ...                         2
# 1          0           4            0  ...                         2
# 2          0           5            0  ...                         2
# 3          1           5            0  ...                         2
# 4          0           4            1  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %% [markdown]
# #we are dropping the class and storing the new dataset in another variable
# x=df.drop('class',axis=1)
# x

# %%
y=df['class']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %% [markdown]
# Now. we'll check if the classes are imbalanced or not in the target column named class.

# %%
y.value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %% [markdown]
# we can see that class is imbalanced , so we'll use SMOTE technique to oversampling the data for balancing the classes with same no.

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
# checking the classes count again
trainy.value_counts()
# Out:
# 0    4208
# 1    4208
# Name: class, dtype: int64

# %% [markdown]
# now, we are done with oversampling .

# %%
trainy
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8411    1
# 8412    1
# 8413    1
# 8414    1
# 8415    1
# Name: class, Length: 8416, dtype: int32

# %%
from sklearn.model_selection  import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
lg=LogisticRegression()

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lg.fit(x_train,y_train)
    pred_test=lg.predict(x_test)
    pred_train=lg.predict(x_train)
    if round(accuracy_score(y_test,pred_test)*100,1)==round(accuracy_score(y_train,pred_train)*100,1):
        print('Random state',i,'score is well')
        print('test score',accuracy_score(y_test,pred_test)*100)
        print('train score',accuracy_score(y_train,pred_train)*100)
# Out:
# Random state 2 score is well
# test score 95.19999999999999
# train score 95.15310047699647
# Random state 3 score is well
# test score 95.01538461538462
# train score 95.03000461609479
# Random state 6 score is well
# test score 94.58461538461539
# train score 94.5837821203262
# Random state 23 score is well
# test score 95.38461538461539
# train score 95.41467918141252
# Random state 28 score is well
# test score 95.07692307692308
# train score 95.0607785813202
# Random state 48 score is well
# test score 95.19999999999999
# train score 95.2146484074473
# Random state 79 score is well
# test score 95.32307692307693
# train score 95.29158332051085
# Random state 80 score is well
# test score 95.19999999999999
# train score 95.15310047699647
# Random state 97 score is well
# test score 95.07692307692308
# train score 95.09155254654561

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
nb=MultinomialNB()

# %%
param={'kernel':['linear','rbf','poly','sigmoid']}
gd=GridSearchCV(svc,param,cv=5)
gd.fit(x,y)
print(gd.best_params_)
{'kernel': 'linear'}
# Out:
# {'kernel': 'linear'}
# {'kernel': 'linear'}

# %%
param={'n_neighbors':[7,5,11],'weights':['uniform','distance'],'algorithm':['auto','bell_tree','kd_tree','brute']}
gd=GridSearchCV(knn,param)
gd.fit(x,y)
print(gd.best_params_)
{'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}

# %%
svc=SVC(kernel='linear')
dtc=DecisionTreeClassifier(criterion='entropy',max_features='log2',splitter='random')
knn=KNeighborsClassifier(n_neighbors=5,weights='distance',algorithm='auto')
nb=MultinomialNB()

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Accuracy Score',accuracy_score(y_test,pred))
    print('Confusion Matrix\n',confusion_matrix(y_test,pred))
    print('Classification Report\n',classification_report(y_test,pred))
    print('F1 score',f1_score(y_test,pred))

# %%
fun(svc)
# Out:
# Accuracy Score 0.9747692307692307
# Confusion Matrix
#  [[803  10]
#  [ 31 781]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       813
#            1       0.99      0.96      0.97       812
#
#     accuracy                           0.97      1625
#    macro avg       0.98      0.97      0.97      1625
# weighted avg       0.98      0.97      0.97      1625
#
# F1 score 0.974422956955708
